# %% [markdown]
# # 靜態網頁的資料爬蟲策略
#
#
# * 了解靜態網頁的資料爬蟲策略
# * 認識適用於靜態網頁爬蟲的相關套件工具：Request
# * 認識適用於靜態網頁爬蟲的相關套件工具：BeatifulSoup

# %% [markdown]
# ## 作業目標
#
# 利用 Request + BeatifulSoup 爬取下列兩個網站內容並解析：
#
# 1. Dcared 網址： https://www.dcard.tw/f
# 2. 知乎： https://www.zhihu.com/explore
#
# 並且回答下面問題：
#
# 1. Request 取回之後該怎麼取出資料，資料型態是什麼？
# 2. 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？
# 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %% [markdown]
# ### 1. Dcard 網址： https://www.dcard.tw/f

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.dcard.tw/f'

r = requests.get(url)
# 想要爬資料的目標網址
response = r.text
# 模擬發送請求的動作

r.encoding = 'utf-8'
#print(response)
print(response[0:3000])
# Out:
# <!DOCTYPE html><html lang="zh-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https://schema.org/WebSite"><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1"/><meta name="apple-mobile-web-app-status-bar-style" content="default"/><link rel="stylesheet" type="text/css" href="https://fonts.googleapis.com/css?family=Roboto:400,300"/><meta name="application-name" content="Dcard"/><meta name="apple-itunes-app" content="app-id=951353454"/><meta name="theme-color" content="#006aa6"/><meta name="mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta name="supported-color-schemes" content="light"/><meta property="fb:app_id" content="211628828926493"/><meta property="fb:pages" content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764"/><meta property="al:ios:app_store_id" content="951353454"/><meta property="al:ios:app_name" content="Dcard"/><meta property="al:android:package" content="com.sparkslab.dcardreader"/><meta property="al:android:app_name" content="Dcard"/><link rel="manifest" href="/_next/static/manifest.json"/><link rel="icon" type="image/png" sizes="16x16" href="/_next/static/images/icon-16-1daa7474e5fe761a7239d12c56b88680.png"/><link rel="icon" type="image/png" sizes="24x24" href="/_next/static/images/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png"/><link rel="icon" type="image/png" sizes="32x32" href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><link rel="icon" type="image/png" sizes="192x192" href="/_next/static/images/icon-192-49149beb434e1f6bccac918f6608564c.png"/><link rel="apple-touch-icon" type="image/png" sizes="57x57" href="/_next/static/images/icon-57-c95fcd930b41dbc6de0495348939582f.png"/><link rel="apple-touch-icon" type="image/png" sizes="72x72" href="/_next/static/images/icon-72-69b64cb9aadc811dce34ea6ac772cd8f.png"/><link rel="apple-touch-icon" type="image/png" sizes="76x76" href="/_next/static/images/icon-76-67203a784694f8378d2f51f24970e2f7.png"/><link rel="apple-touch-icon" type="image/png" sizes="114x114" href="/_next/static/images/icon-114-c58f911deb58868e8cc68ea1e09cc688.png"/><link rel="apple-touch-icon" type="image/png" sizes="120x120" href="/_next/static/images/icon-120-f3ada61716c0cc460c2cbe72b18fb9b4.png"/><link rel="apple-touch-icon" type="image/png" sizes="144x144" href="/_next/static/images/icon-144-679d873aa4b58f1117915545d3fdfa1d.png"/><link rel="apple-touch-icon" type="image/png" sizes="152x152" href="/_next/static/images/icon-152-b7ec982f1f49f590c97611e0e5e9f7f3.png"/><link rel="apple-touch-icon" type="image/png" sizes="180x180" href="/_next/static/images/icon-180-2665760e1b88b5af7a3cfbdc532bae20.png"/><link rel="shortcut icon" type="image/png" href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gt

# %%
print('Request 取回之後該怎麼取出資料，資料型態是什麼？', type(response))
# Out:
# Request 取回之後該怎麼取出資料，資料型態是什麼？ <class 'str'>

# %%
print('為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ ')
soup = BeautifulSoup(response, "html5lib")
print(type(soup))
print(soup)
# Out:
# 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？
# <class 'bs4.BeautifulSoup'>
# <!DOCTYPE html>
# <html lang="zh-TW"><head itemscope="" itemtype="https://schema.org/WebSite" prefix="og: http://ogp.me/ns#"><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/><meta content="default" name="apple-mobile-web-app-status-bar-style"/><link href="https://fonts.googleapis.com/css?family=Roboto:400,300" rel="stylesheet" type="text/css"/><meta content="Dcard" name="application-name"/><meta content="app-id=951353454" name="apple-itunes-app"/><meta content="#006aa6" name="theme-color"/><meta content="yes" name="mobile-web-app-capable"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="light" name="supported-color-schemes"/><meta content="211628828926493" property="fb:app_id"/><meta content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764" property="fb:pages"/><meta content="951353454" property="al:ios:app_store_id"/><meta content="Dcard" property="al:ios:app_name"/><meta content="com.sparkslab.dcardreader" property="al:android:package"/><meta content="Dcard" property="al:android:app_name"/><link href="/_next/static/manifest.json" rel="manifest"/><link href="/_next/static/images/icon-16-1daa7474e5fe761a7239d12c56b88680.png" rel="icon" sizes="16x16" type="image/png"/><link href="/_next/static/images/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png" rel="icon" sizes="24x24" type="image/png"/><link href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png" rel="icon" sizes="32x32" type="image/png"/><link href="/_next/static/images/icon-192-49149beb434e1f6bccac918f6608564c.png" rel="icon" sizes="192x192" type="image/png"/><link href="/_next/static/images/icon-57-c95fcd930b41dbc6de0495348939582f.png" rel="apple-touch-icon" sizes="57x57" type="image/png"/><link href="/_next/static/images/icon-72-69b64cb9aadc811dce34ea6ac772cd8f.png" rel="apple-touch-icon" sizes="72x72" type="image/png"/><link href="/_next/static/images/icon-76-67203a784694f8378d2f51f24970e2f7.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/><link href="/_next/static/images/icon-114-c58f911deb58868e8cc68ea1e09cc688.png" rel="apple-touch-icon" sizes="114x114" type="image/png"/><link href="/_next/static/images/icon-120-f3ada61716c0cc460c2cbe72b18fb9b4.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/><link href="/_next/static/images/icon-144-679d873aa4b58f1117915545d3fdfa1d.png" rel="apple-touch-icon" sizes="144x144" type="image/png"/><link href="/_next/static/images/icon-152-b7ec982f1f49f590c97611e0e5e9f7f3.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/><link href="/_next/static/images/icon-180-2665760e1b88b5af7a3cfbdc532bae20.png" rel="apple-touch-icon" sizes="180x180" type="image/png"/><link href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png" rel="shortcut icon" type="image/png"/><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-TWLTW4M');</script><meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/><meta charset="utf-8"/><meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" name="description"/><meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" property="og:description"/><meta content="website" property="og:type"/><meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" property="twitter:description"/><meta content="https://www.dcard.tw/images/landing.png" itemprop="image" name="image"/><meta content="https://www.dcard.tw/images/landing.png" property="og:image"/><meta content="https://www.dcard.tw/images/landing.png" property="og:image:secure_url"/><meta content="https://www.dcard.tw/images/landing.png" property="twitter:image"/><title>Dcard</title><link href="https://www.dcard.tw/f" rel="canonical"/><meta content="https://www.dcard.tw/f" itemprop="url" name="url"/><meta content="Dcard" property="og:site_name"/><meta content="Dcard" property="og:title"/><meta content="https://www.dcard.tw/f" property="og:url"/><meta content="Dcard" property="twitter:title"/><meta content="dcard://category/all/%E5%85%A8%E9%83%A8/hot" property="al:android:url"/><meta content="dcard://category" property="al:ios:url"/><script type="application/ld+json">{"@context":"https://schema.org","@type":"CollectionPage","name":"Dcard","url":"https://www.dcard.tw/f","description":"廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"}</script><script type="application/ld+json">{"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Dcard","item":"https://www.dcard.tw"},{"@type":"ListItem","position":2,"name":"全部","item":"https://www.dcard.tw/f"}]}</script><meta content="21" name="next-head-count"/><link as="style" href="/_next/static/css/6d1bbc10820647a103b8.css" rel="preload"/><link href="/_next/static/css/6d1bbc10820647a103b8.css" rel="stylesheet"/><link as="script" href="/_next/static/NIE3OWZVJFzIL9D5wkgKW/pages/forum.js" rel="preload"/><link as="script" href="/_next/static/NIE3OWZVJFzIL9D5wkgKW/pages/_app.js" rel="preload"/><link as="script" href="/_next/static/chunks/commons.641ac4d206a9bca94d31.js" rel="preload"/><link as="script" href="/_next/static/chunks/0ea447ec6475b8c633d3a1b91dd0268d5feb3dc2.d6ad95b6df9a06c6bf65.js" rel="preload"/><link as="script" href="/_next/static/chunks/51dc8a8a354304bae9da4fadd05caabbc6c4eb76.07ee27a84520ef266f8c.js" rel="preload"/><link as="script" href="/_next/static/chunks/929bcd95746ea383c65e38e34d0c75f546f39884.695c3577195f34d961ff.js" rel="preload"/><link as="script" href="/_next/static/chunks/94.49a6f11e6783532e05fa.js" rel="preload"/><link as="script" href="/_next/static/chunks/2aa1e8864fecaff8b4840b7e2f303b9afa9b4084.5ed60213c390ef8537df.js" rel="preload"/><link as="script" href="/_next/static/chunks/2776a38d1a5e88024ebd092c2e995ceb690a54b8.78e4a4a398603bb53149.js" rel="preload"/><link as="script" href="/_next/static/chunks/85b95f6a074e49116a04d3b68b2d0e9084216637.fec99550b192bcd14cee.js" rel="preload"/><link as="script" href="/_next/static/chunks/106.cb56c194130296e90044.js" rel="preload"/><link as="script" href="/_next/static/chunks/132.b9755831b17b32b43b57.js" rel="preload"/><link as="script" href="/_next/static/chunks/fdcdd36a85ada1b5b5a815da37369fa06da1f31d.264397419277bc622cac.js" rel="preload"/><link as="script" href="/_next/static/chunks/96.9a419054f1e41c627c31.js" rel="preload"/><link as="script" href="/_next/static/chunks/133.92b3a7a22778d9e4ab39.js" rel="preload"/><link as="script" href="/_next/static/chunks/107.feb64f5b700867c558c1.js" rel="preload"/><link as="script" href="/_next/static/chunks/4126b802a398e40b3edea14683c47b24a1e6f698.5bbd47e68b7f06f37624.js" rel="preload"/><link as="script" href="/_next/static/chunks/92.585a0b38a11854905e8c.js" rel="preload"/><link as="script" href="/_next/static/runtime/webpack-f8 ...
# /* sc-component-id: sc-global-1522344194 */
# body{background-color:#00324e;}
# /* sc-component-id: j5hcf9-0 */
# .jGEwPe{display:none;}
# /* sc-component-id: sc-1rm1ozc-0 */
# .hCDZLD{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .hCDZLD img,.hCDZLD svg{height:100%;width:100%;}.gEBqGb{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:26px;height:26px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .gEBqGb img,.gEBqGb svg{height:100%;width:100%;}.homstF{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:44px;height:44px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .homstF img,.homstF svg{height:100%;width:100%;}.bbbsLJ{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:24px;height:24px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .bbbsLJ img,.bbbsLJ svg{height:100%;width:100%;}.jpXdFc{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:24px;height:24px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .jpXdFc img,.jpXdFc svg{height:100%;width:100%;}.kfXdDt{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:40px;height:40px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .kfXdDt img,.kfXdDt svg{height:100%;width:100%;}.LjbcL{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:24px;height:24px;fill:rgba(0,0,0,0.2);stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .LjbcL img,.LjbcL svg{height:100%;width:100%;}.DkLWL{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:28px;height:28px;fill:#c4c4c4;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .DkLWL img,.DkLWL svg{height:100%;width:100%;}.drkUgx{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .drkUgx img,.drkUgx svg{height:100%;width:100%;}.cdmmlB{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:16px;height:16px;fill:rgba(0,0,0,.6);stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .cdmmlB img,.cdmmlB svg{height:100%;width:100%;}.gvAvJF{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#3397cf;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .gvAvJF img,.gvAvJF svg{height:100%;width:100%;}.bvyBIx{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:18px;height:18px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2, ...
# /* sc-component-id: ih5c0o-0 */
# .fcnNom{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;box-sizing:border-box;outline:none;font-size:16px;line-height:normal;border-radius:4px;padding:0 10px;height:40px;width:100%;-webkit-flex:1;-ms-flex:1;flex:1;color:rgba(0,0,0,.85);border:1px solid rgba(0,0,0,0.25);} .fcnNom::-webkit-input-placeholder{color:#c1c2c5;} .fcnNom::-moz-placeholder{color:#c1c2c5;} .fcnNom:-ms-input-placeholder{color:#c1c2c5;} .fcnNom::placeholder{color:#c1c2c5;}
# /* sc-component-id: sc-1ehu1w3-0 */
# .bRgdkb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;} .bRgdkb form{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:#00588a;border-radius:4px;overflow:hidden;width:100%;}
# /* sc-component-id: sc-1ehu1w3-1 */
# .gIBcSB{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;font-size:14px;color:#fff;}
# /* sc-component-id: sc-1ehu1w3-2 */
# .osVsG{background:#006aa6;border:1px solid #00588a;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:0 4px 4px 0;padding:0 9px;cursor:pointer;outline:none;}
# /* sc-component-id: sc-17b0qgb-0 */
# .dDFxdu{position:-webkit-sticky;position:sticky;top:60px;background:#fafafa;border-bottom:1px solid #dedede;padding:0 60px;z-index:10;}
# /* sc-component-id: sc-17b0qgb-3 */
# .emtuRP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: sc-17b0qgb-4 */
# .kbapDD{height:100%;white-space:nowrap;} .kbapDD:first-child{padding-left:0;} .kbapDD a{color:#3397cf;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 20px;} .kbapDD a::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}.hZDMRR{height:100%;white-space:nowrap;} .hZDMRR:first-child{padding-left:0;} .hZDMRR a{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 20px;} .hZDMRR a::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}
# /* sc-component-id: y8ceb6-0 */
# .kcUIbq{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:14px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:none;background:#3397cf;color:#fff;} .kcUIbq:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .kcUIbq:hover{background:#006aa6;}.dIwkJi{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:13px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:none;background:#3397cf;color:#fff;} .dIwkJi:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);}.imklgR{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:14px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:1px solid #fff;color:#fff;background:transparent;} .imklgR:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);}.jFVlKa{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:14px;padding:0 16px;height:37px;pointer-events:none;opacity:0.5;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:none;background:#3397cf;color:#fff;} .jFVlKa:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .jFVlKa:hover{background:#006aa6;}
# /* sc-component-id: iogflz-0 */
# .hdPZrL{text-align:center;color:rgba(0,0,0,.6);font-size:15px;line-height:1.6;}
# /* sc-component-id: iogflz-1 */
# .kjmpEs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}
# /* sc-component-id: iogflz-3 */
# .eOQEjS{height:120px;margin-bottom:20px;}
# /* sc-component-id: iogflz-4 */
# .eoBgRD{color:rgba(0,0,0,.6);font-size:17px;font-weight:500;margin-bottom:10px;}
# /* sc-component-id: iogflz-5 */
# .ezgRmy{color:rgba(0,0,0,.35);}
# /* sc-component-id: sc-1fexymf-0 */
# .eueuzJ{background-color:#fff;position:relative;height:100vh;width:100%;padding-top:60px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;} .eueuzJ img{height:180px;}.elJwoJ{background-color:#fff;position:relative;height:100vh;width:100%;padding-top:0px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;} .elJwoJ img{height:180px;}
# /* sc-component-id: sc-1fexymf-1 */
# .EjNRP{margin-top:20px;}
# /* sc-component-id: sc-1f7f012-0 */
# .iUJhUp{height:76px;width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 16px;border-bottom:1px solid #d9d9d9;background-color:#fff;}
# /* sc-component-id: sc-1f7f012-1 */
# .VoRSe{-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-1f7f012-2 */
# .sfCyH{width:44px;height:44px;}
# /* sc-component-id: sc-1f7f012-3 */
# .deRddy{margin-left:16px;}
# /* sc-component-id: sc-1f7f012-4 */
# .gNeIRi{margin:0;color:rgba(0,0,0,0.75);font-size:17px;}
# /* sc-component-id: sc-1f7f012-5 */
# .hsZPUX{margin:8px 0 0;color:rgba(0,0,0,0.5);font-size:13px;}
# /* sc-component-id: sc-17x0g9b-0 */
# .geHAXF{width:60px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}.blXIQQ{width:px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:0 2px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}.ldlYQO{width:px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;padding:0 12px;}
# /* sc-component-id: sc-17x0g9b-1 */
# .iFfAVt{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;line-height:1;color:#fff;}
# /* sc-component-id: sc-1lftjqb-0 */
# .ioHIdq{margin-right:16px;}
# /* sc-component-id: ezgous-0 */
# .ktvxUR{display:block;height:100%;}
# /* sc-component-id: sc-1h3w01r-0 */
# .BYkrm{height:100%;padding:16px 0;display:block;}.kElwiP{height:100%;padding:10px 0;display:block;}
# /* sc-component-id: sc-1ccznvc-0 */
# .bTbYIC{max-width:1280px;height:100%;margin:auto;padding:0 20px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-1ccznvc-1 */
# .dacFof{height:100%;-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-1ccznvc-2 */
# .btyxdF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;}
# /* sc-component-id: sc-1xoh8vd-0 */
# .eQqQOc{height:48px;width:100%;background:#006aa6;}
# /* sc-component-id: sc-1xoh8vd-1 */
# .eBbPuw{max-width:px;height:100%;margin:auto;padding:0 16px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-right:4px;}
# /* sc-component-id: p0732u-2 */
# .hOBRZF{display:inline-block;height:100%;}
# /* sc-component-id: sc-18hjmuk-0 */
# .gaeSlb{position:fixed;top:0;z-index:11;height:60px;width:100%;background:#006aa6;}
# /* sc-component-id: sc-18hjmuk-1 */
# .gEMehv{padding:0 20px;max-width:432px;min-width:200px;height:30px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: sc-4rlot1-0 */
# .yLWL{position:relative;width:100%;height:100%;}
# /* sc-component-id: sc-4rlot1-1 */
# .cPcxXe{position:absolute;top:0;left:0;bottom:0;right:0;}
# /* sc-component-id: sc-4rlot1-3 */
# .crieHS{box-sizing:border-box;}
# /* sc-component-id: sc-4rlot1-5 */
# .dlyvKU{--track-radius:3px;--track-size:8px;--transition-duration:200ms;position:absolute;overflow:hidden;border-radius:var(--track-radius);background-color:transparent;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-transition:background var(--transition-duration);transition:background var(--transition-duration);left:0;bottom:0;height:var(--track-size);width:100%;} .dlyvKU:hover{background-color:rgba(0,0,0,0.3);}
# /* sc-component-id: sc-4rlot1-6 */
# .fHIqqP{--track-radius:3px;--track-size:8px;--transition-duration:200ms;position:absolute;overflow:hidden;border-radius:var(--track-radius);background-color:transparent;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-transition:background var(--transition-duration);transition:background var(--transition-duration);width:var(--track-size);height:100%;top:0;right:0;} .fHIqqP:hover{background-color:rgba(0,0,0,0.3);}
# /* sc-component-id: sc-4rlot1-8 */
# .egNafV{--thumb-size:6px;--thumb-margin:calc((var(--track-size) - var(--thumb-size)) / 2);cursor:pointer;border-radius:var(--track-radius);background:rgba(0,0,0,0.5);opacity:0;-webkit-transition:opacity var(--transition-duration);transition:opacity var(--transition-duration);height:var(--thumb-size);margin:var(--thumb-margin) 0;} .sc-4rlot1-0:hover .egNafV{opacity:1;} .sc-4rlot1-4:hover .egNafV{height:var(--track-size);margin:0;}
# /* sc-component-id: sc-4rlot1-9 */
# .coCYVj{--thumb-size:6px;--thumb-margin:calc((var(--track-size) - var(--thumb-size)) / 2);cursor:pointer;border-radius:var(--track-radius);background:rgba(0,0,0,0.5);opacity:0;-webkit-transition:opacity var(--transition-duration);transition:opacity var(--transition-duration);width:var(--thumb-size);margin:0 var(--thumb-margin);} .sc-4rlot1-0:hover .coCYVj{opacity:1;} .sc-4rlot1-4:hover .coCYVj{width:var(--track-size);margin:0;}
# /* sc-component-id: sc-1szhyqg-0 */
# .fizRcc{display:grid;max-width:1280px;margin:auto;padding:60px 20px 0 0;grid-template-columns:[start] 208px [mainLeft] auto [mainRight] 300px [end];-webkit-transition:grid-template-columns .5s;transition:grid-template-columns .5s;}
# /* sc-component-id: sc-1szhyqg-1 */
# .bFQTAq{grid-column:start / mainLeft;}
# /* sc-component-id: sc-1szhyqg-2 */
# .cBkHYU{min-width:calc(728px + 24px);grid-column:mainLeft / mainRight;}.bVslMr{min-width:calc(undefinedpx + 0px);grid-column:mainLeft / mainRight;}
# /* sc-component-id: sc-1szhyqg-3 */
# .iGPfkn{grid-column:mainRight / end;}
# /* sc-component-id: sc-1wxmy6k-0 */
# .jtIqJY{-webkit-flex:1;-ms-flex:1;flex:1;margin:0 0px;min-height:calc(100vh - 48px);min-width:0px;padding-top:0px;height:100%;}.gCznGk{margin:0 12px;min-height:calc(100vh - 80px);min-width:728px;padding-top:20px;height:100%;}
# /* sc-component-id: sc-1wxmy6k-1 */
# .hyWHQx{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-top:0px;}
# /* sc-component-id: sc-1wxmy6k-2 */
# .fViMUW{height:100%;background:#fafafa;border-radius:4px 4px 0 0;}
# /* sc-component-id: sc-86hs1l-0 */
# .eUKldl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:32px;color:rgba(0,0,0,.6);font-size:14px;border-radius:4px;background:#efefef;padding:0 16px;white-space:nowrap;}.fBIBLZ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:32px;color:rgba(0,0,0,.6);font-size:13px;border-radius:4px;background:#efefef;padding:0 16px;white-space:nowrap;}
# /* sc-component-id: d14s4-0 */
# .kWuhLO{overflow-y:hidden;}
# /* sc-component-id: d14s4-1 */
# .eWrDFH{overflow-x:auto;overflow-y:hidden;}
# /* sc-component-id: d14s4-2 */
# .fYgReK{white-space:nowrap;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:64px;padding:0 0px;} .fYgReK::after{content:'';-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;height:64px;width:0px;}
# /* sc-component-id: d14s4-3 */
# .jnFGmH{display:block;}
# /* sc-component-id: d14s4-4 */
# .fnUokS{display:inline-block;padding-right:8px;padding-top:8px;} .fnUokS:last-child{padding-right:0;}.fGPsmL{display:inline-block;padding-right:16px;padding-top:16px;} .fGPsmL:last-child{padding-right:0;}.RpCDL{display:inline-block;padding-right:16px;padding-top:px;} .RpCDL:last-child{padding-right:0;}
# /* sc-component-id: sc-142n6ln-0 */
# .hHxGJn{overflow:hidden;position:relative;max-width:100%;max-height:60vh;}.litoaQ{overflow:hidden;position:relative;max-width:100%;max-height:vh;}
# /* sc-component-id: sc-142n6ln-1 */
# .hbmeDj{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:60vh;}.brONUK{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:vh;}
# /* sc-component-id: sc-142n6ln-2 */
# .cEJeML{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:60vh;position:absolute;top:0;left:0;}.bJNJxt{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:vh;position:absolute;top:0;left:0;}
# /* sc-component-id: sc-8n4pv8-0 */
# .fOXphs{position:relative;height:120px;padding:16px 0;width:100%;}.dxHwn{position:relative;height:64px;padding:13px 0;width:100%;}
# /* sc-component-id: sc-1wy11h7-0 */
# .hZdjnC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin:8px 0 6px;padding:0 10px;border:1px solid rgb(233,233,233);border-radius:4px;background:#fff;box-shadow:0 1px 2px #ddd;line-height:1.3;max-width:430px;width:100%;min-height:65px;overflow:hidden;}
# /* sc-component-id: sc-1wy11h7-1 */
# .dOLhZS{-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: sc-1wy11h7-2 */
# .egSNep{margin-right:10px;border-radius:3px;overflow:hidden;background-color:#006aa6;}.rpDwW{margin-right:10px;border-radius:3px;padding:5px;overflow:hidden;background-color:#006aa6;}
# /* sc-component-id: sc-1wy11h7-3 */
# .iDaSAx{-webkit-flex:1;-ms-flex:1;flex:1;min-width:0;}
# /* sc-component-id: sc-1wy11h7-4 */
# .lpbimL{white-space:nowrap;text-overflow:ellipsis;overflow:hidden;font-size:16px;font-weight:bold;line-height:1.3;color:rgba(0,0,0,.85);padding-bottom:5px;}
# /* sc-component-id: sc-1wy11h7-5 */
# .ivyOUa{white-space:nowrap;text-overflow:ellipsis;overflow:hidden;font-size:14px;color:rgba(0,0,0,.35);line-height:16px;height:16px;}
# /* sc-component-id: sc-1hi1x4o-0 */
# .kWVqST{margin:10px 0;}
# /* sc-component-id: sc-4ihej7-0 */
# .cGpUxm{white-space:pre-wrap;}
# /* sc-component-id: sc-6yh43a-0 */
# .hNXlIX{font-size:18px;line-height:1.6;word-wrap:break-word;}.lcmPyT{font-size:15px;color:rgba(0,0,0,.6);line-height:1.6;word-wrap:break-word;}
# /* sc-component-id: sc-6yh43a-1 */
# .hGzOyW{padding-bottom:22px;}.edNClc{padding-bottom:16px;}
# /* sc-component-id: sc-6yh43a-2 */
# .hLEWVo{padding:10px 0;border-top:1px solid rgb(233,233,233);border-bottom:1px solid rgb(233,233,233);}
# /* sc-component-id: sc-6yh43a-3 */
# .kFgrBi{font-size:16px;line-height:30px;color:rgba(0,0,0,.35);padding-bottom:3px;}.faVWSy{font-size:13px;line-height:30px;color:rgba(0,0,0,.35);padding-bottom:3px;}
# /* sc-component-id: fsyoh-0 */
# .eNjcqm{font-size:30px;line-height:1.5;font-weight:500;word-wrap:break-word;color:rgba(0,0,0,.95);}.cnnesX{font-size:19px;line-height:1.5;font-weight:500;word-wrap:break-word;color:rgba(0,0,0,.95);}
# /* sc-component-id: sc-405p19-0 */
# .gRJhgY{background:#fafafa;padding:0 60px 0;}.hRbpDK{background:#fff;padding:0 16px 0;}
# /* sc-component-id: sc-405p19-1 */
# .kwWzjf{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-bottom:0px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.eLVJIY{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-bottom:5px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-405p19-2 */
# .elTwdm{-webkit-flex:1;-ms-flex:1;flex:1;overflow:hidden;}
# /* sc-component-id: sc-405p19-3 */
# .cGHCFQ{font-size:14px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-top:12px;}.krNBKU{font-size:13px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-top:12px;}
# /* sc-component-id: sc-405p19-4 */
# .gkJnjG{color:rgba(0,0,0,.35);white-space:nowrap;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;} .gkJnjG:not(:last-child)::after{content:'·';padding:0 0.5em;}
# /* sc-component-id: sc-405p19-6 */
# .AvCE{padding:22px 0 40px;}.cDxkdQ{padding:16px 0 24px;}
# /* sc-component-id: sc-405p19-7 */
# .eZBsBf{padding-bottom:16px;}.hQKgLK{padding-bottom:24px;}
# /* sc-component-id: sc-1heqsqc-0 */
# .jtdKe{border-radius:50%;overflow:hidden;}
# /* sc-component-id: sc-1heqsqc-1 */
# .ezVUnZ{background:#2490bf;color:#fff;font-size:25.6px;height:40px;width:40px;line-height:40px;text-align:center;border-radius:50%;}.ccflTX{background:#cb3a6b;color:#fff;font-size:25.6px;height:40px;width:40px;line-height:40px;text-align:center;border-radius:50%;}.irzYfI{background:#cb3a6b;color:#fff;font-size:12.8px;height:20px;width:20px;line-height:20px;text-align:center;border-radius:50%;}.joizCB{background:#2490bf;color:#fff;font-size:12.8px;height:20px;width:20px;line-height:20px;text-align:center;border-radius:50%;}.kGvIbr{background:#2490bf;color:#fff;font-size:64px;height:100px;width:100px;line-height:100px;text-align:center;border-radius:50%;}.eyJxfp{background:#2490bf;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}.dPFFvS{background:#cb3a6b;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}.dteuZm{background:#2490bf;color:#fff;font-size:30.72px;height:48px;width:48px;line-height:48px;text-align:center;border-radius:50%;}.gBsHiW{background:#cb3a6b;color:#fff;font-size:30.72px;height:48px;width:48px;line-height:48px;text-align:center;border-radius:50%;}
# /* sc-component-id: sc-1heqsqc-2 */
# .ilqlpH{display:block;border-radius:50%;object-fit:cover;}
# /* sc-component-id: vt1ivp-0 */
# .eJVCKv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-left:12px;}
# /* sc-component-id: vt1ivp-1 */
# .hhGcWV{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:rgba(0,0,0,.35);font-size:14px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;} .hhGcWV:hover > *{fill:#ea5c5c;}.jPDTQd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:rgba(0,0,0,.35);font-size:13px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}
# /* sc-component-id: vt1ivp-2 */
# .kKpHuw{cursor:pointer;display:block;margin-right:14px;}.jtGEVN{cursor:pointer;display:block;margin-right:8px;}
# /* sc-component-id: vt1ivp-3 */
# .kRIwhc{background:rgba(0,0,0,0.05);width:1px;height:16px;margin:0 2px 0 10px;}.jdPPuq{background:rgba(0,0,0,0.05);width:1px;height:24px;margin:0 8px 0 16px;}
# /* sc-component-id: vt1ivp-4 */
# .keVKMY{cursor:pointer;} .keVKMY:hover{fill:#3397cf;}
# /* sc-component-id: sc-1wrppqn-0 */
# .kaIfrV{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:16px;}.bKjCHy{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:13px;}
# /* sc-component-id: sc-1wrppqn-1 */
# .ezkBZa{padding-right:15px;}
# /* sc-component-id: sc-1wrppqn-2 */
# .irdkmf{-webkit-flex:1;-ms-flex:1;flex:1;overflow:hidden;}
# /* sc-component-id: sc-1wrppqn-3 */
# .fIdNgN{color:rgba(0,0,0,.85);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: sc-1wrppqn-4 */
# .emkLLu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;color:rgba(0,0,0,.35);padding-top:3px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: sc-1wrppqn-5 */
# .PJors{color:rgba(0,0,0,.35);}
# /* sc-component-id: sc-1wrppqn-6 */
# .kNUiuk{margin:0 0.5em;border-right:1px solid #dfdfdf;}
# /* sc-component-id: sc-1wrppqn-7 */
# .iGCAto{-webkit-flex:1;-ms-flex:1;flex:1;overflow:hidden;cursor:pointer;}
# /* sc-component-id: sc-1wrppqn-8 */
# .gziKlw{margin-left:3px;}
# /* sc-component-id: sc-1t5l7uc-0 */
# .chpjJz{color:rgba(0,0,0,.85);font-size:18px;padding:16px 0;border-bottom:1px solid rgb(233,233,233);position:relative;}.cGDMvT{color:rgba(0,0,0,.85);font-size:18px;padding:16px 0;border-bottom:1px solid transparent;position:relative;}.blhVoR{color:rgba(0,0,0,.85);font-size:18px;padding:26px 30px;border-bottom:1px solid transparent;position:relative;}.jLZYil{color:rgba(0,0,0,.85);font-size:18px;padding:26px 20px;border-bottom:1px solid transparent;position:relative;}
# /* sc-component-id: sc-1t5l7uc-1 */
# .iuZiCA{margin-top:20px;padding:10px 0;border-top:1px solid rgb(233,233,233);border-bottom:1px solid rgb(233,233,233);}
# /* sc-component-id: sc-1t5l7uc-2 */
# .gPZLIV{font-size:16px;line-height:30px;color:rgba(0,0,0,.35);margin-bottom:3px;}.NdBvW{font-size:13px;line-height:30px;color:rgba(0,0,0,.35);margin-bottom:3px;}
# /* sc-component-id: sc-1t5l7uc-3 */
# .dKskmE{color:rgba(0,0,0,.85);font-size:18px;line-height:1.6;padding-top:24px;word-break:break-all;} .dKskmE .sc-142n6ln-0 > img{height:25vh;}.cRuwCS{color:rgba(0,0,0,.6);font-size:15px;line-height:1.6;padding-top:16px;word-break:break-all;} .cRuwCS .sc-142n6ln-0 > img{height:25vh;}.ccmcRL{color:rgba(0,0,0,.85);font-size:18px;line-height:1.6;padding-top:24px;word-break:break-all;} .ccmcRL .sc-142n6ln-0 > img{height:initial;}.oYafH{color:rgba(0,0,0,.6);font-size:15px;line-height:1.6;padding-top:16px;word-break:break-all;} .oYafH .sc-142n6ln-0 > img{height:initial;}
# /* sc-component-id: sc-1jf3ag7-0 */
# .bYxfmO{padding:0 60px;}.dKRAFa{padding:0 16px;}
# /* sc-component-id: sc-1jf3ag7-1 */
# .fBhzEe{border-bottom:1px solid rgb(233,233,233);padding:2px 0;color:rgba(0,0,0,.35);font-size:16px;font-weight:400;}.iIxzGL{border-bottom:1px solid rgba(0,0,0,0.05);padding:12px 0;color:rgba(0,0,0,.35);font-size:13px;font-weight:400;}
# /* sc-component-id: nxot29-0 */
# .iYpwSB{padding:0 60px;}.dBpdSw{padding:0 16px;}
# /* sc-component-id: nxot29-1 */
# .gxgEFV{background:#fff;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:16px 0;border-bottom:1px solid rgb(233,233,233);}.kNHERa{background:#fafafa;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;border-bottom:1px solid rgb(233,233,233);}
# /* sc-component-id: ku7hkd-0 */
# .cjrmwT{background:#f5f5f5;padding:0 60px;padding-bottom:120px;}
# /* sc-component-id: ku7hkd-1 */
# .dqhhnS{border-top:1px solid rgb(233,233,233);padding:24px 0;}.eEtwtF{border-top:1px solid transparent;padding:24px 0;}
# /* sc-component-id: ku7hkd-2 */
# .eXJZdk{background:#fff;color:rgba(0,0,0,.35);border-radius:4px;border:1px solid rgb(233,233,233);line-height:60px;font-size:18px;padding-left:17px;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;cursor:text;}
# /* sc-component-id: sc-11usotw-0 */
# .xdxSb{padding:0 60px;}.ifmEFn{background:#fff;padding:0 16px;}
# /* sc-component-id: sc-11usotw-1 */
# .cfuySD{border-top:1px solid rgb(233,233,233);padding:14px 0;}
# /* sc-component-id: dc3vxu-0 */
# .iQyzcv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;}
# /* sc-component-id: dc3vxu-1 */
# .ghEcOz{display:none;}
# /* sc-component-id: dc3vxu-2 */
# .blPfcv{position:relative;height:18px;width:18px;border-radius:15%;border:1px solid rgba(0,0,0,0.15);margin-right:8px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;} .blPfcv:after{position:absolute;display:block;box-sizing:border-box;content:'';top:50%;left:50%;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);height:75%;width:75%;border-radius:15%;visibility:visible;-webkit-transition:background-color 0.15s cubic-bezier(.4,0,.2,1);transition:background-color 0.15s cubic-bezier(.4,0,.2,1);cursor:pointer;}
# /* sc-component-id: sc-2vjtkz-0 */
# .gvUcHv{width:64px;height:32px;border-radius:8px;padding:0;font-size:14px;font-weight:500;}.dWvjeq{width:64px;height:32px;border-radius:8px;padding:0;font-size:14px;font-weight:500;color:rgba(0,0,0,0.75);background-color:rgba(0,16,32,0.06);} .dWvjeq:hover{background-color:rgba(0,0,0,.2);}.fmGEio{width:56px;height:32px;border-radius:8px;padding:0;font-size:14px;font-weight:500;}.hcVWAC{width:56px;height:32px;border-radius:8px;padding:0;font-size:14px;font-weight:500;width:70px;color:rgba(0,0,0,0.75);background-color:rgba(0,16,32,0.06);}
# /* sc-component-id: olnp72-0 */
# .dddAwk{background:#edad1d;color:#fff;padding:14px 0;font-size:14px;text-align:center;}
# /* sc-component-id: olnp72-1 */
# .gbDaxp{padding:22px 60px;}.jUDRHq{padding:16px 16px;}
# /* sc-component-id: olnp72-2 */
# .hXEXYl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: olnp72-3 */
# .fqicHK{padding-right:15px;}
# /* sc-component-id: olnp72-5 */
# .egoBgt{-webkit-flex:1;-ms-flex:1;flex:1;overflow:hidden;}
# /* sc-component-id: olnp72-6 */
# .KGljv{font-size:16px;color:rgba(0,0,0,.85);white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}.hlWhQH{font-size:13px;color:rgba(0,0,0,.85);white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: olnp72-9 */
# .dRQLtg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-top:22px;}
# /* sc-component-id: olnp72-10 */
# .jDbAbp{background:#edad1d;color:#fff;font-size:18px;padding:4px 7px;}
# /* sc-component-id: olnp72-16 */
# .hDDfOc{-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: sc-1f0e53e-0 */
# .lmrpoS{padding:0 8px;border:none;background:none;height:100%;cursor:pointer;outline:none;} .lmrpoS:last-child{padding-right:0;}
# /* sc-component-id: sc-1f0e53e-1 */
# .sc-1f0e53e-0:hover .bFtSbL{fill:danger;}.sc-1f0e53e-0:hover .gXspeR{fill:#3397cf;}
# /* sc-component-id: shoolh-0 */
# .hVnLGx{-webkit-transform:rotateZ(0deg);-ms-transform:rotateZ(0deg);transform:rotateZ(0deg);}
# /* sc-component-id: sc-1y3l27m-0 */
# .giHJKI{padding-right:60px;}.kbUmu{padding-right:16px;}
# /* sc-component-id: sc-1y3l27m-1 */
# .gVRfJF{background:#f0b941;color:#fff;padding:0 20px;height:100%;margin-left:16px;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border:none;cursor:pointer;line-height:52px;} .gVRfJF:disabled{background:#a6a6a6;cursor:not-allowed;}
# /* sc-component-id: brwf0-0 */
# .lguUxw{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:100%;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-1kuvyve-0 */
# .HPJWH{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;}.fDYFAm{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;pointer-events:none;}
# /* sc-component-id: sc-1kuvyve-1 */
# .cYcyMQ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.ifcbUA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;opacity:0.75;}
# /* sc-component-id: sc-1kuvyve-2 */
# .fSMjKp{display:block;height:24px;width:24px;border-radius:50%;border:2px solid #fafafa;margin-left:-4px;} .fSMjKp:first-child{margin-left:0;}.cJwINH{display:block;height:20px;width:20px;border-radius:50%;border:2px solid #fafafa;margin-left:-4px;} .cJwINH:first-child{margin-left:0;}.nArqW{display:block;height:21px;width:21px;border-radius:50%;border:2px solid #fff;margin-left:-4px;} .nArqW:first-child{margin-left:0;}.cdwOPp{display:block;height:20px;width:20px;border-radius:50%;border:2px solid #fff;margin-left:-4px;} .cdwOPp:first-child{margin-left:0;}
# /* sc-component-id: sc-1kuvyve-3 */
# .ejolKO{padding-left:6px;}
# /* sc-component-id: sc-13t0dac-0 */
# .hevWLQ{padding:0 60px;background:#fafafa;}.gglUe{padding:0 16px;background:#fff;}
# /* sc-component-id: sc-13t0dac-1 */
# .lhzXMC{padding:6px 0;color:rgba(0,0,0,.35);font-size:14px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.bUZMTr{padding:12px 0;color:rgba(0,0,0,.35);font-size:13px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-top:1px solid rgba(0,0,0,0.05);border-bottom:1px solid rgba(0,0,0,0.05);}
# /* sc-component-id: sc-13t0dac-2 */
# .jueEHw{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-13t0dac-3 */
# .cGIYVA{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}
# /* sc-component-id: sc-13t0dac-4 */
# .dJllVu span{border-color:#fafafa;}.gYwJjF span{border-color:#fff;}
# /* sc-component-id: sc-1qqve8m-0 */
# .bdkwEy{color:rgba(0,0,0,.35);padding:40px 0;}.illTCe{color:rgba(0,0,0,.35);}
# /* sc-component-id: sc-1qqve8m-1 */
# .iyxdng{display:grid;grid-template-columns:repeat(2,1fr);grid-gap:0 8px;margin-top:10px;padding:0 60px;}.XeqfP{display:grid;grid-template-columns:repeat(1,1fr);grid-gap:0 8px;margin-top:0px;padding:0 16px;}
# /* sc-component-id: sc-1qqve8m-2 */
# .cGkAqu{position:relative;min-width:0;} .cGkAqu:last-child{border-bottom:none;} .cGkAqu a{color:rgba(0,0,0,.85);font-size:16px;font-weight:bold;display:block;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;padding:8px 0 8px 18px;} .cGkAqu a:hover{color:#797979;} .cGkAqu a::before{content:'';width:7px;height:7px;position:absolute;top:0;left:0;bottom:0;border-radius:50%;margin:auto;background:#3397cf;}.cuKSrd{position:relative;min-width:0;border-bottom:1px solid rgba(0,0,0,0.05);} .cuKSrd:last-child{border-bottom:none;} .cuKSrd a{color:rgba(0,0,0,.85);font-size:15px;display:block;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;padding:16px 0 16px 23px;} .cuKSrd a:hover{color:#797979;} .cuKSrd a::before{content:'';width:7px;height:7px;position:absolute;top:0;left:0;bottom:0;border-radius:50%;margin:auto;background:#3397cf;}
# /* sc-component-id: sc-9kodai-0 */
# .cNPYp{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;height:52px;}.jzGhoF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;height:50px;}
# /* sc-component-id: sc-9kodai-1 */
# ...
# /* sc-component-id: tylbbx-2 */
# .kweWZV{height:8px;}
# /* sc-component-id: tylbbx-3 */
# .cQYWuI{color:#000;white-space:nowrap;font-size:30px;font-weight:500;margin-left:10px;} .cQYWuI > a{color:inherit;}
# /* sc-component-id: tylbbx-4 */
# .elaRzv{height:100%;margin:0 0 0 auto;}.bnuCPY{height:100%;margin:0 0 0 auto;margin:0;-webkit-flex:1;-ms-flex:1;flex:1;margin:0;width:100%;}.kWMfDl{height:100%;margin:0 0 0 auto;margin:0;width:100%;}.eAaNol{height:100%;margin:0 0 0 auto;margin:0;-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: sc-19z7wht-0 */
# .gHzERj{padding-top:20px;}.jyllvl{padding-top:0;}
# /* sc-component-id: sc-1uq8rde-1 */
# .iFJzTD{width:100%;padding-top:calc(100% / 3);position:relative;}
# /* sc-component-id: sc-1uq8rde-2 */
# .cPyPId{position:absolute;top:0;left:0;width:100%;height:100%;object-fit:cover;}
# /* sc-component-id: sc-1f4gosl-0 */
# .iVpJct{background-color:#fff;padding-top:16px;}
# /* sc-component-id: sc-1f4gosl-1 */
# .xNIDx{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 16px;}
# /* sc-component-id: sc-1f4gosl-2 */
# .bPLbwr{-webkit-flex:1;-ms-flex:1;flex:1;color:rgba(0,0,0,.85);font-size:24px;font-weight:600;margin:0 10px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: sc-1f4gosl-3 */
# .jUyCFo{padding:0 16px;margin-top:13px;color:rgba(0,0,0,.6);font-size:15px;}
# /* sc-component-id: sc-1f4gosl-4 */
# .dNzmDd{margin:8px 16px 0;}
# /* sc-component-id: xi0w8b-0 */
# .dBpzwh{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding:0px 60px;border-bottom:1px solid rgb(233,233,233);}
# /* sc-component-id: ijlje-0 */
# .fLLbxl{cursor:pointer;} .fLLbxl:hover{fill:#3397cf;}
# /* sc-component-id: sc-1efwr6o-0 */
# .iHfqWy{padding:6px 30px;}.hPKftV{padding:0;background:#fff;min-height:100%;}
# /* sc-component-id: jlamu4-0 */
# .ikqLpQ{position:-webkit-sticky;position:sticky;top:0;border-bottom:1px solid #dedede;padding:0 16px;z-index:10;background:#fff;}.bphmPI{position:-webkit-sticky;position:sticky;top:0;border-bottom:1px solid #dedede;padding:0 60px;z-index:10;background:#fafafa;}
# /* sc-component-id: jlamu4-1 */
# .jeipMt{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding:20px 0 16px;}
# /* sc-component-id: jlamu4-2 */
# .zFRvn{-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: jlamu4-3 */
# .hUMQLe{color:rgba(0,0,0,.95);font-size:18px;margin-bottom:8px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: jlamu4-4 */
# .gLmFOd{color:rgba(0,0,0,.35);}
# /* sc-component-id: jlamu4-5 */
# .dWRRYa{padding:0 0.5em;} .dWRRYa::before{content:'‧';}
# /* sc-component-id: jlamu4-8 */
# .iRsvkF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: jlamu4-9 */
# .irTaNc a{color:#3397cf;padding:20px 0;margin-right:20px;display:block;position:relative;} .irTaNc a::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}.fkpOlW a{color:rgba(0,0,0,.35);padding:20px 0;margin-right:20px;display:block;position:relative;} .fkpOlW a::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}
# /* sc-component-id: karf5m-0 */
# .fQvfed{padding-top:0;}.iVbNfV{padding-top:24px;}
# /* sc-component-id: sc-1wpo23g-0 */
# .fMcVje{width:100%;border-top:1px solid rgba(0,0,0,0.15);} .fMcVje *{color:rgba(0,0,0,.35);}
# /* sc-component-id: sc-1wpo23g-1 */
# .ggsaiW{width:640px;margin:auto;padding:20px 0;}
# /* sc-component-id: sc-1wpo23g-2 */
# .jdcDGi{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}
# /* sc-component-id: eoh6nh-0 */
# .dNHhJm{padding:30px 0 15px;width:100%;background-color:#fff;border-bottom:1px solid rgba(0,0,0,0.15);}
# /* sc-component-id: eoh6nh-1 */
# .fPFxdD{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;min-width:720px;max-width:1280px;margin:auto;}
# /* sc-component-id: eoh6nh-5 */
# .gJEPDY{height:100px;width:100px;}
# /* sc-component-id: eoh6nh-6 */
# .guPsiZ{margin-top:15px;font-size:24px;line-height:33px;color:rgba(0,0,0,.8);}
# /* sc-component-id: eoh6nh-7 */
# .gayUeh{font-size:14px;line-height:23px;color:rgba(0,0,0,.45);}
# /* sc-component-id: eoh6nh-10 */
# .fTBoxx{margin:8px 0 20px;color:rgba(0,0,0,.35);font-size:14px;}
# /* sc-component-id: sc-13za6a4-1 */
# .eSosZd{padding-bottom:8px;color:rgba(0,0,0,.35);font-size:14px;}
# /* sc-component-id: sc-13za6a4-2 */
# .HVhzX{--border-radius:4px;background:#fff;border:1px solid rgb(233,233,233);border-top-width:0;padding:20px;border-top-width:1px;border-radius:var(--border-radius) var(--border-radius) 0 0;border-radius:0 0 var(--border-radius) var(--border-radius);margin-bottom:32px;}
# /* sc-component-id: tqxbqo-0 */
# .iBpnOf{min-height:100vh;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:100%;padding-top:60px;background-color:rgb(250,250,250);}
# /* sc-component-id: tqxbqo-1 */
# .eYepin{-webkit-flex:1;-ms-flex:1;flex:1;width:640px;margin:30px auto;}
# /* sc-component-id: sc-103epvp-0 */
# .hNibsq{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;height:calc(100vh - 60px);width:100%;padding-top:60px;}
# /* sc-component-id: sc-103epvp-1 */
# .kHmVCy{height:100%;max-width:1280px;}
# /* sc-component-id: sc-18tm7py-0 */
# .gaiaqI{padding-top:24px;}
# /* sc-component-id: sc-18000pa-0 */
# .cpJrdV{padding:20px 40px;}
# /* sc-component-id: sc-18000pa-1 */
# .ecDMPX{background:#fff;border:1px solid rgb(222,222,222);box-shadow:rgba(0,0,0,0.05) 0px 2px 4px 0px;border-radius:4px;}
# /* sc-component-id: sc-18000pa-2 */
# .jkRjri{color:rgba(0,0,0,.45);padding:20px 20px 5px;}
# /* sc-component-id: sc-1p0ai6z-0 */
# .jkqQbr{padding:20px;}
# /* sc-component-id: sc-1p0ai6z-1 */
# .eBLkfO{color:rgba(0,0,0,.95);font-size:18px;}
# /* sc-component-id: sc-1p0ai6z-2 */
# .gKMdVA{color:rgba(0,0,0,.6);padding-top:0.8em;}
# /* sc-component-id: sc-1p0ai6z-3 */
# .SejeO{border-bottom:1px solid rgb(222,222,222);margin:0 20px;}
# /* sc-component-id: sc-1w8wbbt-0 */
# .erUhyZ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-1w8wbbt-1 */
# .cXiJdA{padding-left:20px;}
# /* sc-component-id: sc-1mrq29n-0 */
# .laZelY{padding-top:0px;}
# /* sc-component-id: sc-1u22hei-1 */
# .dLEnYi{margin-bottom:10px;font-size:16px;color:rgba(0,0,0,.8);line-height:1;text-align:start;}
# /* sc-component-id: sc-1u22hei-2 */
# .fpUWLw{margin-bottom:20px;}
# /* sc-component-id: sc-1u22hei-3 */
# .kMSWcz{border-radius:4px;border:none;border:1px solid rgba(0,0,0,0.15);}
# /* sc-component-id: sc-1u22hei-6 */
# .bimSFP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-top:10px;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;font-size:14px;color:rgba(0,0,0,.8);}
# /* sc-component-id: sc-1u22hei-7 */
# .gAbqtv{-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: sc-1u22hei-8 */
# .atpIK{color:#3397cf;font-size:14px;cursor:pointer;}
# /* sc-component-id: sc-1u22hei-9 */
# .bylGzy{margin:0 5px;}
# /* sc-component-id: sc-1u22hei-10 */
# .hOYKtp{margin-top:4px;width:100%;}
# /* sc-component-id: sc-1534md9-0 */
# .kAHdPw{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}
# /* sc-component-id: sc-1534md9-2 */
# .faLJNL{font-size:14px;border-radius:4px;border:1px solid transparent;background:none;padding:0 16px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;background:#425f9c;color:#fff;} .faLJNL:not(:first-child){margin-top:20px;}
# /* sc-component-id: sc-1534md9-3 */
# .eqlEiP{font-size:14px;border-radius:4px;border:1px solid transparent;background:none;padding:0 16px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;border-color:rgba(0,0,0,0.15);} .eqlEiP:not(:first-child){margin-top:20px;}
# /* sc-component-id: sc-1534md9-4 */
# .bmrhao{-webkit-flex:1;-ms-flex:1;flex:1;text-align:center;padding:12px;}
# /* sc-component-id: ohr5wm-1 */
# .jckDJo{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:rgba(0,0,0,.35);margin:20px 0;} .jckDJo:before{margin-right:16px;} .jckDJo:after{margin-left:16px;} .jckDJo:before,.jckDJo:after{background:#dfdfdf;display:block;content:'';height:1px;width:100%;}
# /* sc-component-id: ohr5wm-2 */
# .wPsvb{margin-top:8px;color:rgba(0,0,0,.45);font-size:14px;line-height:2;} .wPsvb a{color:rgba(0,0,0,.45);border-bottom:1px solid rgba(0,0,0,.45);}
# /* sc-component-id: sc-7cq3z5-0 */
# .jhNhvE{height:100%;text-align:center;}
# /* sc-component-id: sc-7cq3z5-1 */
# .kvSUh{height:250px;margin:auto;}
# /* sc-component-id: sc-7cq3z5-2 */
# .iVGFSe{color:#fff;font-size:32px;line-height:45px;margin-top:0.67em;}
# /* sc-component-id: sc-7cq3z5-3 */
# .ljAMVO{margin:0 0 20px;color:#fff;font-size:24px;line-height:36px;opacity:0.6;}
# /* sc-component-id: sc-7cq3z5-4 */
# .htWTdJ{font-size:18px;opacity:0.6;padding:2px 16px;}
# /* sc-component-id: sc-6ge0nz-0 */
# .cIQVEE{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}
# /* sc-component-id: sc-6ge0nz-1 */
# .hENuQg{-webkit-flex:1;-ms-flex:1;flex:1;overflow:hidden;padding:0 5px;}
# /* sc-component-id: sc-6ge0nz-2 */
# .kAYDbe{width:100%;}
# /* sc-component-id: b71we9-0 */
# .cQHQtD{width:100%;max-width:1140px;margin:auto;}
# /* sc-component-id: b71we9-1 */
# .hTQwm{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:space-evenly;-webkit-justify-content:space-evenly;-ms-flex-pack:space-evenly;justify-content:space-evenly;padding:50px 0;}
# /* sc-component-id: b71we9-2 */
# .tChPm{padding-top:80px;} @media (max-width:1024px){.tChPm{display:none;}}
# /* sc-component-id: b71we9-3 */
# .glDCsD{background:#fff;border-radius:4px;overflow:hidden;width:460px;}
# /* sc-component-id: b71we9-4 */
# .iWqEkv{text-align:center;padding:30px 50px;}
# /* sc-component-id: b71we9-5 */
# .cjGYlu{margin-bottom:10px;font-size:2em;font-weight:400;line-height:1.6;}
# /* sc-component-id: b71we9-6 */
# .bAmBXu{margin-bottom:30px;display:none;}
# /* sc-component-id: b71we9-7 */
# .dJsbwa{background:#efefef;padding:30px 50px;text-align:center;}
# /* sc-component-id: b71we9-8 */
# .gzZbZd{color:rgba(0,0,0,.45);margin-bottom:1em;}
# /* sc-component-id: b71we9-9 */
# .cRymFS{height:auto;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding-bottom:30px;display:none;} .cRymFS a{color:rgba(0,0,0,.6);font-size:13px;font-weight:bold;margin-right:16px;} .cRymFS a:not(:last-child):after{content:'';margin-left:16px;border-right:1px solid rgba(0,0,0,.6);}
# /* sc-component-id: sc-1716hri-0 */
# .bjzrBG{height:100vh;width:100%;padding-top:60px;}
# /* sc-component-id: sc-1716hri-1 */
# .kYhBMN{position:relative;height:100%;width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;text-align:center;}</style></head><body><div id="__next"><div class="sc-18hjmuk-0 gaeSlb"><div class="sc-1ccznvc-0 bTbYIC"><div class="sc-1ccznvc-1 dacFof"><a class="sc-1h3w01r-0 BYkrm" href="/f" title="Dcard"><img alt="Dcard" class="ezgous-0 ktvxUR" src="/_next/static/images/logo-6c547910a47669647856d4c9cc62f0ba.svg"/></a><div class="sc-18hjmuk-1 gEMehv"><div class="sc-1ehu1w3-0 bRgdkb"><form><input aria-label="搜尋文章、看板、人物" class="ih5c0o-0 fcnNom sc-1ehu1w3-1 gIBcSB" name="query" placeholder="搜尋文章、看板、人物" type="search"/><button class="sc-1ehu1w3-2 osVsG" title="搜尋"><span class="sc-1rm1ozc-0 hCDZLD sc-1ehu1w3-5 bYknYf" fill="#fff" role="img" size="20"><svg viewBox="0 0 28 28"><path d="M22.9 21.2l-4.5-4.5A7.5 7.5 0 1017 18l4.5 4.5a.5.5 0 00.8 0l.5-.5a.5.5 0 000-.8zm-10.4-3.5a5.6 5.6 0 115.6-5.6 5.6 5.6 0 01-5.6 5.6z"></path></svg></span></button><button class="j5hcf9-0 jGEwPe" type="submit"></button></form></div></div></div><div class="sc-1ccznvc-2 btyxdF" role="navigation"><a class="sc-17x0g9b-0 geHAXF" href="/signup?redirect=%2Ff" role="button"><span class="sc-17x0g9b-1 iFfAVt">登入</span></a><div class="p0732u-2 hOBRZF"><a class="sc-17x0g9b-0 blXIQQ" role="button" title="更多"><span class="sc-17x0g9b-1 iFfAVt"><span class="sc-1rm1ozc-0 gEBqGb sc-17x0g9b-2 bGGVPx" fill="#fff" role="img" size="26"><svg viewBox="0 0 24 24"><path d="M11.08 15.62l-4.69-4.69a1.31 1.31 0 01.92-2.24h9.38a1.31 1.31 0 01.92 2.24l-4.69 4.69a1.3 1.3 0 01-1.84 0z"></path><path d="M0 0h24v24H0z" fill="none"></path></svg></span></span></a></div></div></div></div><div class="sc-1szhyqg-0 fizRcc"><div class="sc-1szhyqg-1 bFQTAq"><div class="sc-1xg2zzw-0 PiZcj"><a href="/forum/all"><div class="m096xq-0 jjwIvU"><div class="sc-1xg2zzw-1 fqtTLp"><span class="sc-1rm1ozc-0 jpXdFc sc-1xg2zzw-2 eMXSfJ" fill="#fff" role="img" size="24"><svg viewBox="0 0 24 24"><path d="M18.95 3H5.05A2.04 2.04 0 003 5.04v13.91A2.04 2.04 0 005.05 21h13.9A2.05 2.05 0 0021 18.96V5.03A2.05 2.05 0 0018.95 3zM6.68 17.73a1.64 1.64 0 111.64-1.64 1.64 1.64 0 01-1.64 1.64zm0-4.1A1.64 1.64 0 118.32 12a1.64 1.64 0 01-1.64 1.64zm0-4.08A1.64 1.64 0 118.32 7.9a1.64 1.64 0 01-1.64 1.64zm11.86 6.77a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.1a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.45a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.08a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1z" data-name="icon_md_forum"></path></svg></span></div><div class="sc-1x63gba-1 eFYrsX">所有看板</div></div></a><a href="/forum/popular"><div class="m096xq-0 jjwIvU"><div class="sc-1xg2zzw-1 fqtTLp"><span class="sc-1rm1ozc-0 jpXdFc sc-1xg2zzw-2 eMXSfJ" fill="#fff" role="img" size="24"><svg viewBox="0 0 24 24"><path d="M19.5 14.5a7.5 7.5 0 01-15 0 12.9 12.9 0 012.21-7.25l.02-.03a.18.18 0 01.04-.05.5.5 0 01.31-.15.51.51 0 01.55.46A3.36 3.36 0 0010.9 10a3.26 3.26 0 003.2-3.5 16.5 16.5 0 00-.32-2.9 1.63 1.63 0 01-.04-.19V3.4a.5.5 0 01.49-.5.51.51 0 01.28.08.45.45 0 01.1.09A15.95 15.95 0 0119.5 14.5zm-3.59-1.55a12.97 12.97 0 00-.22-1.32.5.5 0 00-.83-.27 7.93 7.93 0 01-3.73 1.77 2.94 2.94 0 00-2.63 2.93c0 2.55 3.3 4.32 5.95 1.5a5.75 5.75 0 001.46-4.6z" data-name="ic_hot"></path></svg></span></div><div class="sc-1x63gba-1 eFYrsX">即時熱門看板</div></div></a><a href="/goods"><div class="m096xq-0 jjwIvU"><div class="sc-1xg2zzw-1 fqtTLp"><span class="sc-1rm1ozc-0 jpXdFc gpcsqh-0 hRuOXd" fill="#fff" role="img" size="24"><svg viewBox="0 0 24 24"><path d="M8 21a2 2 0 11-2-2 2 2 0 012 2zm10-2a2 2 0 102 2 2 2 0 00-2-2zm2.44-1.19v-1a.5.5 0 00-.5-.5H6.3a.5.5 0 01-.4-.81L7.05 14a1 1 0 00.16-.93L4.48 4.72A1 1 0 004 4.13l-1.85-.9a.5.5 0 00-.67.23l-.48.9a.51.51 0 00.24.64l1.47.71 2.43 7.48-.82 1a2.49 2.49 0 00-.09 2.94 2.62 2.62  ...

# %% [markdown]
# ### 2. 知乎： https://www.zhihu.com/explore

# %%
url = 'https://www.zhihu.com/explore'
r = requests.get(url)
r.encoding = 'utf-8'

print(r.text[0:600])
# Out:
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Request</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>

# %% [markdown]
# ### 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %%
url2 = 'https://www.zhihu.com/explore'

headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6,ja;q=0.5',
    'cache-control': 'max-age=0',
    'cookie': '_zap=a5634a47-a806-4828-8ab4-2cbc03734bda; d_c0="AFBoGjc1fg6PTus2_H76YgMM3xvztVHRnCs=|1541767835"; __gads=ID=18e1196642fc5994:T=1544975081:S=ALNI_MZ2lQjiLHPlLxjVqGGH6o-EiL2luQ; z_c0="2|1:0|10:1551204934|4:z_c0|92:Mi4xM1FkMERnQUFBQUFBVUdnYU56Vi1EaVlBQUFCZ0FsVk5SdEJpWFFDUXZ6REVHVWw0QWtXblh6WGt4T183ekdxNFhn|fa542d11758c34207cdd6a1edf85de768ac02624c8cb53aa687017af49accd7b"; tst=r; q_c1=aed50b9b158344d6ac78a230c8970d83|1560948516000|1543510922000; __utmv=51854390.100--|2=registration_date=20190226=1^3=entry_date=20181130=1; _xsrf=13cd498d-6139-4c50-99a6-df5c749dd64c; tgw_l7_route=4860b599c6644634a0abcd4d10d37251; __utma=51854390.567487929.1560948518.1560950333.1562469680.3; __utmb=51854390.0.10.1562469680; __utmc=51854390; __utmz=51854390.1562469680.3.3.utmcsr=localhost:8888|utmccn=(referral)|utmcmd=referral|utmcct=/notebooks/day2-example.ipynb',
    'referer': 'http://localhost:8888/notebooks/day2-example.ipynb',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36'
}
r2 = requests.get(url2, headers=headers)

r2.encoding = 'utf-8'
print(r2.text[0:600])
# Out:
# <!doctype html>
# <html lang="zh" data-hairline="true" data-theme="light"><head><meta charSet="utf-8"/><title data-react-helmet="true">发现 - 知乎</title><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1"/><meta name="renderer" content="webkit"/><meta name="force-rendering" content="webkit"/><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><meta name="google-site-verification" content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg"/><meta name="description" property="og:description" content="有问题，上知乎。知乎，可信赖的问答社区，以让每个人高效获得可信赖的解答为使命。知乎凭借认真、专业和友善的社区氛围，结构化、易获得的
